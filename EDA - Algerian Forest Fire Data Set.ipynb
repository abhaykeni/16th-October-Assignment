# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("G:\Assignments\EDA\Data Sets\Algerian_forest_fires_dataset_UPDATE.csv",header = 1)

# %%
data
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI Classes
# 0    0.5  not fire
# 1    0.4  not fire
# 2    0.1  not fire
# ...

# %%
#Slicing Operation of a Data Frame
k = 2
size = 125
for i in range(k):
    df = data[size*i:size*(i+1)]
    df.to_csv(f'Data_{i+1}.csv', index=False)

br_data = pd.read_csv("Data_1.csv")
bar_data = pd.read_csv("Data_2.csv")
br_data = br_data.drop([122,123,124])
br_data.to_csv("Data_1.csv")
bar_data.to_csv("Data_2.csv")
bar_data = pd.read_csv("Data_2.csv")
br_data = pd.read_csv("Data_1.csv")

# %%
br_data
# Out:
#      Unnamed: 0  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  \
# 0             0    1      6  2012           29   57   18    0.0  65.7  3.4
# 1             1    2      6  2012           29   61   13    1.3  64.4  4.1
# 2             2    3      6  2012           26   82   22   13.1  47.1  2.5
# 3             3    4      6  2012           25   89   13    2.5  28.6  1.3
# 4             4    5      6  2012           27   77   16    0.0  64.8  3.0
# ..          ...  ...    ...   ...          ...  ...  ...    ...   ...  ...
# 117         117   26      9  2012           31   54   11    0.0  82.0  6.0
# 118         118   27      9  2012           31   66   11    0.0  85.7  8.3
# 119         119   28      9  2012           32   47   14    0.7  77.5  7.1
# 120         120   29      9  2012           26   80   16    1.8  47.4  2.9
# 121         121   30      9  2012           25   78   14    1.4  45.0  1.9
#
#        DC  ISI  BUI  FWI Classes
# ...

# %%
bar_data
# Out:
#      Unnamed: 0  day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC  \
# 0             0    1      6  2012           32   71   12    0.7  57.1   2.5
# 1             1    2      6  2012           30   73   13    4.0  55.7   2.7
# 2             2    3      6  2012           29   80   14    2.0  48.7   2.2
# 3             3    4      6  2012           30   64   14    0.0  79.4   5.2
# 4             4    5      6  2012           32   60   14    0.2  77.1   6.0
# ..          ...  ...    ...   ...          ...  ...  ...    ...   ...   ...
# 117         117   26      9  2012           30   65   14    0.0  85.4  16.0
# 118         118   27      9  2012           28   87   15    4.4  41.1   6.5
# 119         119   28      9  2012           27   87   29    0.5  45.9   3.5
# 120         120   29      9  2012           24   54   18    0.1  79.7   4.3
# 121         121   30      9  2012           24   64   15    0.2  67.3   3.8
#
#        DC  ISI   BUI  FWI Classes
# ...

# %%
br_data.columns
#List of all features present in data set
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
bar_data.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
bar_data = bar_data.drop("Unnamed: 0",axis=1)
br_data = br_data.drop("Unnamed: 0",axis=1)

# %%
br_data.info()
# No missing value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          122 non-null    int64
#  1   month        122 non-null    int64
#  2   year         122 non-null    int64
#  3   Temperature  122 non-null    int64
#  4    RH          122 non-null    int64
#  5    Ws          122 non-null    int64
#  6   Rain         122 non-null    float64
#  7   FFMC         122 non-null    float64
#  8   DMC          122 non-null    float64
#  9   DC           122 non-null    float64
#  10  ISI          122 non-null    float64
#  11  BUI          122 non-null    float64
#  12  FWI          122 non-null    float64
#  13  Classes      122 non-null    object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 13.5+ KB

# %%
bar_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          122 non-null    int64
#  1   month        122 non-null    int64
#  2   year         122 non-null    int64
#  3   Temperature  122 non-null    int64
#  4    RH          122 non-null    int64
#  5    Ws          122 non-null    int64
#  6   Rain         122 non-null    float64
#  7   FFMC         122 non-null    float64
#  8   DMC          122 non-null    float64
#  9   DC           122 non-null    float64
#  10  ISI          122 non-null    float64
#  11  BUI          122 non-null    float64
#  12  FWI          122 non-null    float64
#  13  Classes      122 non-null    object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 13.5+ KB

# %%
#Statiscal info about the Bejiah Data Set
br_data.describe().T
# Out:
#              count         mean        std     min       25%      50%  \
# day          122.0    15.754098   8.843274     1.0     8.000    16.00
# month        122.0     7.500000   1.115259     6.0     7.000     7.50
# year         122.0  2012.000000   0.000000  2012.0  2012.000  2012.00
# Temperature  122.0    31.180328   3.320401    22.0    29.000    31.00
#  RH          122.0    67.975410  11.154411    45.0    60.000    68.00
#  Ws          122.0    16.000000   2.848807    11.0    14.000    16.00
# Rain         122.0     0.842623   2.409208     0.0     0.000     0.00
# FFMC         122.0    74.672951  15.558713    28.6    65.925    80.90
# DMC          122.0    12.314754  11.274360     0.7     3.725     9.45
# DC           122.0    53.160656  51.778265     6.9    10.050    35.55
# ISI          122.0     3.655738   3.021768     0.0     1.125     2.65
# BUI          122.0    15.426230  14.474302     1.1     5.100    11.20
# ...

# %%
bar_data.describe().T
# Out:
#              count         mean        std     min       25%      50%  \
# day          122.0    15.754098   8.843274     1.0     8.000    16.00
# month        122.0     7.500000   1.115259     6.0     7.000     7.50
# year         122.0  2012.000000   0.000000  2012.0  2012.000  2012.00
# Temperature  122.0    33.163934   3.675608    24.0    30.000    34.00
#  RH          122.0    55.901639  15.716186    21.0    43.250    56.00
#  Ws          122.0    15.008197   2.692186     6.0    14.000    15.00
# Rain         122.0     0.678689   1.486759     0.0     0.000     0.00
# FFMC         122.0    81.102459  12.244064    37.9    77.650    84.85
# DMC          122.0    17.031967  12.995068     0.9     7.325    13.15
# DC           122.0    45.415574  42.927562     7.3    14.700    31.50
# ISI          122.0     5.863934   4.803667     0.1     1.825     4.60
# BUI          122.0    17.920492  13.870785     1.4     7.400    13.90
# ...

# %%
#To categorise the data
br_data.dtypes
# Out:
# day              int64
# month            int64
# year             int64
# Temperature      int64
#  RH              int64
#  Ws              int64
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI            float64
# Classes         object
# dtype: object

# %%
bar_data.dtypes
# Out:
# day              int64
# month            int64
# year             int64
# Temperature      int64
#  RH              int64
#  Ws              int64
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI            float64
# Classes         object
# dtype: object

# %%
br_num_col = [fea for fea in br_data.columns if br_data[fea].dtype != "O"]
br_cat_col = [fea for fea in br_data.columns if br_data[fea].dtype == "O"]

# %%
bar_num_col = [fea for fea in bar_data.columns if bar_data[fea].dtype != "O"]
bar_cat_col = [fea for fea in bar_data.columns if bar_data[fea].dtype == "O"]

# %%
br_num_col
# Out:
# ['day',
#  'month',
#  'year',
#  'Temperature',
#  ' RH',
#  ' Ws',
#  'Rain ',
#  'FFMC',
#  'DMC',
#  'DC',
#  'ISI',
#  'BUI',
#  'FWI']

# %%
br_cat_col
# Out:
# ['Classes  ']

# %%
bar_num_col
# Out:
# ['day',
#  'month',
#  'year',
#  'Temperature',
#  ' RH',
#  ' Ws',
#  'Rain ',
#  'FFMC',
#  'DMC',
#  'DC',
#  'ISI',
#  'BUI',
#  'FWI']

# %%
bar_cat_col
# Out:
# ['Classes  ']

# %%
br_data[br_num_col]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  \
# 0      1      6  2012           29   57   18    0.0  65.7  3.4   7.6  1.3
# 1      2      6  2012           29   61   13    1.3  64.4  4.1   7.6  1.0
# 2      3      6  2012           26   82   22   13.1  47.1  2.5   7.1  0.3
# 3      4      6  2012           25   89   13    2.5  28.6  1.3   6.9  0.0
# 4      5      6  2012           27   77   16    0.0  64.8  3.0  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...  ...   ...  ...
# 117   26      9  2012           31   54   11    0.0  82.0  6.0  16.3  2.5
# 118   27      9  2012           31   66   11    0.0  85.7  8.3  24.9  4.0
# 119   28      9  2012           32   47   14    0.7  77.5  7.1   8.8  1.8
# 120   29      9  2012           26   80   16    1.8  47.4  2.9   7.7  0.3
# 121   30      9  2012           25   78   14    1.4  45.0  1.9   7.5  0.2
#
#      BUI  FWI
# 0    3.4  0.5
# 1    3.9  0.4
# 2    2.7  0.1
# 3    1.7  0.0
# ...

# %%
br_data[br_cat_col]
# Out:
#        Classes
# 0    not fire
# 1    not fire
# 2    not fire
# 3    not fire
# 4    not fire
# ..           ...
# 117  not fire
# 118      fire
# 119  not fire
# 120  not fire
# 121  not fire
#
# [122 rows x 1 columns]

# %%
bar_data[bar_num_col]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC    DC  ISI  \
# 0      1      6  2012           32   71   12    0.7  57.1   2.5   8.2  0.6
# 1      2      6  2012           30   73   13    4.0  55.7   2.7   7.8  0.6
# 2      3      6  2012           29   80   14    2.0  48.7   2.2   7.6  0.3
# 3      4      6  2012           30   64   14    0.0  79.4   5.2  15.4  2.2
# 4      5      6  2012           32   60   14    0.2  77.1   6.0  17.6  1.8
# ..   ...    ...   ...          ...  ...  ...    ...   ...   ...   ...  ...
# 117   26      9  2012           30   65   14    0.0  85.4  16.0  44.5  4.5
# 118   27      9  2012           28   87   15    4.4  41.1   6.5   8.0  0.1
# 119   28      9  2012           27   87   29    0.5  45.9   3.5   7.9  0.4
# 120   29      9  2012           24   54   18    0.1  79.7   4.3  15.2  1.7
# 121   30      9  2012           24   64   15    0.2  67.3   3.8  16.5  1.2
#
#       BUI  FWI
# 0     2.8  0.2
# 1     2.9  0.2
# 2     2.6  0.1
# ...

# %%
bar_data[bar_cat_col]
# Out:
#         Classes
# 0     not fire
# 1     not fire
# 2     not fire
# 3     not fire
# 4     not fire
# ..            ...
# 117       fire
# 118   not fire
# 119   not fire
# 120   not fire
# 121  not fire
#
# [122 rows x 1 columns]

# %%
#Check a missing value
br_data.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# dtype: int64

# %%
#Check a missing value
bar_data.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# dtype: int64

# %%
# To check any duplicate rows
br_data.duplicated().sum()
# Out:
# 0

# %%
# To check any duplicate rows
bar_data.duplicated().sum()
# Out:
# 0

# %%
br_data.nunique()
# Out:
# day             31
# month            4
# year             1
# Temperature     15
#  RH             39
#  Ws             13
# Rain            25
# FFMC           101
# DMC             94
# DC             108
# ISI             67
# BUI             99
# FWI             71
# Classes          2
# dtype: int64

# %%
bar_data.nunique()
# Out:
# day             31
# month            4
# year             1
# Temperature     17
#  RH             55
#  Ws             15
# Rain            27
# FFMC            99
# DMC            105
# DC             105
# ISI             81
# BUI            110
# FWI             90
# Classes          2
# dtype: int64

# %%
br_data.corr()
# Out:
#                 month  year  Temperature        RH        Ws     Rain   \
# month        1.000000   NaN    -0.035708 -0.088025 -0.007804  0.145180
# year              NaN   NaN          NaN       NaN       NaN       NaN
# Temperature -0.035708   NaN     1.000000 -0.660151 -0.228035 -0.486947
#  RH         -0.088025   NaN    -0.660151  1.000000  0.245774  0.329163
#  Ws         -0.007804   NaN    -0.228035  0.245774  1.000000  0.349321
# Rain         0.145180   NaN    -0.486947  0.329163  0.349321  1.000000
# FFMC        -0.040746   NaN     0.748423 -0.653153 -0.211069 -0.573476
# DMC         -0.007624   NaN     0.541489 -0.347080  0.039394 -0.265371
# DC          -0.006211   NaN     0.532838 -0.314271  0.099231 -0.283652
# ISI         -0.011281   NaN     0.663871 -0.586410 -0.039266 -0.366425
# BUI         -0.009113   NaN     0.542210 -0.338233  0.062212 -0.271951
# FWI          0.003330   NaN     0.608367 -0.476067  0.029637 -0.292914
#
# ...

# %%
bar_data.corr()
# Out:
#                       day         month  year  Temperature        RH  \
# day          1.000000e+00  5.358691e-17   NaN     0.026168  0.008625
# month        5.358691e-17  1.000000e+00   NaN    -0.084676 -0.009430
# year                  NaN           NaN   NaN          NaN       NaN
# Temperature  2.616760e-02 -8.467577e-02   NaN     1.000000 -0.598309
#  RH          8.625210e-03 -9.430222e-03   NaN    -0.598309  1.000000
#  Ws          3.063310e-02 -7.844745e-02   NaN    -0.258208  0.141436
# Rain        -1.445983e-01 -1.400570e-01   NaN    -0.129718  0.149027
# FFMC         1.550250e-01  8.833190e-02   NaN     0.573122 -0.645540
# DMC          4.667436e-01  1.366589e-01   NaN     0.389748 -0.379057
# DC           4.877965e-01  2.913300e-01   NaN     0.284506 -0.265698
# ISI          7.710321e-02  1.172411e-01   NaN     0.538246 -0.692335
# BUI          4.797601e-01  1.850881e-01   NaN     0.367756 -0.360802
# FWI          2.762744e-01  1.469336e-01   NaN     0.500590 -0.604374
#
# ...

# %%
br_data.cov()
# Out:
#                 month  year  Temperature          RH         Ws      Rain   \
# month        1.243802   0.0    -0.132231   -1.095041  -0.024793   0.390083
# year         0.000000   0.0     0.000000    0.000000   0.000000   0.000000
# Temperature -0.132231   0.0    11.025064  -24.450075  -2.157025  -3.895353
#  RH         -1.095041   0.0   -24.450075  124.420878   7.809917   8.845685
#  Ws         -0.024793   0.0    -2.157025    7.809917   8.115702   2.397521
# Rain         0.390083   0.0    -3.895353    8.845685   2.397521   5.804284
# FFMC        -0.707025   0.0    38.664422 -113.353563  -9.355372 -21.496276
# DMC         -0.095868   0.0    20.270871  -43.648395   1.265289  -7.208072
# DC          -0.358678   0.0    91.607980 -181.509240  14.637190 -35.384012
# ISI         -0.038017   0.0     6.660940  -19.765560  -0.338017  -2.667602
# BUI         -0.147107   0.0    26.058867  -54.608441   2.565289  -9.483359
# ...

# %%
bar_data.corr()
# Out:
#                       day         month  year  Temperature        RH  \
# day          1.000000e+00  5.358691e-17   NaN     0.026168  0.008625
# month        5.358691e-17  1.000000e+00   NaN    -0.084676 -0.009430
# year                  NaN           NaN   NaN          NaN       NaN
# Temperature  2.616760e-02 -8.467577e-02   NaN     1.000000 -0.598309
#  RH          8.625210e-03 -9.430222e-03   NaN    -0.598309  1.000000
#  Ws          3.063310e-02 -7.844745e-02   NaN    -0.258208  0.141436
# Rain        -1.445983e-01 -1.400570e-01   NaN    -0.129718  0.149027
# FFMC         1.550250e-01  8.833190e-02   NaN     0.573122 -0.645540
# DMC          4.667436e-01  1.366589e-01   NaN     0.389748 -0.379057
# DC           4.877965e-01  2.913300e-01   NaN     0.284506 -0.265698
# ISI          7.710321e-02  1.172411e-01   NaN     0.538246 -0.692335
# BUI          4.797601e-01  1.850881e-01   NaN     0.367756 -0.360802
# FWI          2.762744e-01  1.469336e-01   NaN     0.500590 -0.604374
#
# ...

# %%
for col in br_cat_col:
    print(br_data[col].value_counts(normalize=True) * 100)
# Out:
# not fire    51.639344
# fire        48.360656
# Name: Classes  , dtype: float64

# %%
for col in bar_cat_col:
    print(bar_data[col].value_counts(normalize=True) * 100)
# Out:
# fire        64.754098
# not fire    35.245902
# Name: Classes  , dtype: float64

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features - Bejaia', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(br_num_col)):
    plt.subplot(5, 3, i+1)
    sns.distplot(x=br_data[br_num_col[i]],color='b')
    plt.xlabel(br_num_col[i])
    plt.tight_layout()

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features - Bel Abes', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(bar_num_col)):
    plt.subplot(5, 3, i+1)
    sns.distplot(x=bar_data[bar_num_col[i]],color='b')
    plt.xlabel(bar_num_col[i])
    plt.tight_layout()

# %%
plt.figure(figsize=(10, 5))
plt.suptitle('Univariate Analysis of Categorical Features - Bejaia', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
sns.countplot(x=br_data[br_cat_col[0]],color='b')
plt.xlabel(br_cat_col[0])
plt.tight_layout()

# %%
plt.figure(figsize=(10, 5))
plt.suptitle('Univariate Analysis of Categorical Features - Bel Abes', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
sns.countplot(x=bar_data[br_cat_col[0]],color='b')
plt.xlabel(bar_cat_col[0])
plt.tight_layout()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.stripplot(x=br_cat_col[0],y=br_data[br_num_col[0]],data=br_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(br_num_col[0])
plt.tight_layout()
plt.subplot(1,2,2)
sns.stripplot(x=bar_cat_col[0],y=br_data[bar_num_col[0]],data=bar_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(bar_num_col[0])
plt.tight_layout()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.stripplot(x=br_cat_col[0],y=br_data[br_num_col[1]],data=br_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(br_num_col[1])
plt.tight_layout()
plt.subplot(1,2,2)
sns.stripplot(x=bar_cat_col[0],y=br_data[bar_num_col[1]],data=bar_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(bar_num_col[1])
plt.tight_layout()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.stripplot(x=br_cat_col[0],y=br_data[br_num_col[2]],data=br_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(br_num_col[2])
plt.tight_layout()
plt.subplot(1,2,2)
sns.stripplot(x=bar_cat_col[0],y=br_data[bar_num_col[2]],data=bar_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(bar_num_col[2])
plt.tight_layout()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.stripplot(x=br_cat_col[0],y=br_data[br_num_col[3]],data=br_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(br_num_col[3])
plt.tight_layout()
plt.subplot(1,2,2)
sns.stripplot(x=bar_cat_col[0],y=br_data[bar_num_col[3]],data=bar_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(bar_num_col[3])
plt.tight_layout()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.stripplot(x=br_cat_col[0],y=br_data[br_num_col[4]],data=br_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(br_num_col[4])
plt.tight_layout()
plt.subplot(1,2,2)
sns.stripplot(x=bar_cat_col[0],y=br_data[bar_num_col[4]],data=bar_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(bar_num_col[4])
plt.tight_layout()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.stripplot(x=br_cat_col[0],y=br_data[br_num_col[5]],data=br_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(br_num_col[5])
plt.tight_layout()
plt.subplot(1,2,2)
sns.stripplot(x=bar_cat_col[0],y=br_data[bar_num_col[5]],data=bar_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(bar_num_col[5])
plt.tight_layout()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.stripplot(x=br_cat_col[0],y=br_data[br_num_col[6]],data=br_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(br_num_col[6])
plt.tight_layout()
plt.subplot(1,2,2)
sns.stripplot(x=bar_cat_col[0],y=br_data[bar_num_col[6]],data=bar_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(bar_num_col[6])
plt.tight_layout()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.stripplot(x=br_cat_col[0],y=br_data[br_num_col[7]],data=br_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(br_num_col[7])
plt.tight_layout()
plt.subplot(1,2,2)
sns.stripplot(x=bar_cat_col[0],y=br_data[bar_num_col[7]],data=bar_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(bar_num_col[7])
plt.tight_layout()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.stripplot(x=br_cat_col[0],y=br_data[br_num_col[8]],data=br_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(br_num_col[8])
plt.tight_layout()
plt.subplot(1,2,2)
sns.stripplot(x=bar_cat_col[0],y=br_data[bar_num_col[8]],data=bar_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(bar_num_col[8])
plt.tight_layout()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.stripplot(x=br_cat_col[0],y=br_data[br_num_col[9]],data=br_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(br_num_col[9])
plt.tight_layout()
plt.subplot(1,2,2)
sns.stripplot(x=bar_cat_col[0],y=br_data[bar_num_col[9]],data=bar_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(bar_num_col[9])
plt.tight_layout()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.stripplot(x=br_cat_col[0],y=br_data[br_num_col[10]],data=br_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(br_num_col[10])
plt.tight_layout()
plt.subplot(1,2,2)
sns.stripplot(x=bar_cat_col[0],y=br_data[bar_num_col[10]],data=bar_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(bar_num_col[10])
plt.tight_layout()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.stripplot(x=br_cat_col[0],y=br_data[br_num_col[11]],data=br_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(br_num_col[11])
plt.tight_layout()
plt.subplot(1,2,2)
sns.stripplot(x=bar_cat_col[0],y=br_data[bar_num_col[11]],data=bar_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(bar_num_col[11])
plt.tight_layout()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.stripplot(x=br_cat_col[0],y=br_data[br_num_col[12]],data=br_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(br_num_col[12])
plt.tight_layout()
plt.subplot(1,2,2)
sns.stripplot(x=bar_cat_col[0],y=br_data[bar_num_col[12]],data=bar_data,jitter=True, dodge=True, palette='viridis')
plt.xlabel(bar_num_col[12])
plt.tight_layout()

# %%
plt.figure(figsize = (15,10))
sns.heatmap(br_data.corr(), cmap="CMRmap", annot=True)
plt.show()

# %%
plt.figure(figsize = (15,10))
sns.heatmap(bar_data.corr(), cmap="CMRmap", annot=True)
plt.show()
